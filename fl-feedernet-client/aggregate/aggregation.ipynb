# %%
import json
import requests
import shutil
import os
import aggregation
# Out:
# config :  {
# 	"current_round": 10,
# 	"max_round": 10,
# 	"CDM_execution_list": {
# 		"9": {
# 			"16016": 20,
# 			"16017": 20,
# 			"16018": 20,
# 			"16019": 20,
# 			"16020": 20,
# 			"16021": 20,
# 			"16022": 20,
# 			"16023": 20,
# 			"16024": 20,
# 			"16025": 20,
# 			"16026": 20,
# 			"16027": 20
# 		}
# 	},
# 	"project_name": "M/L Tensorflow Analysis Test",
# 	"user_id": "fnet05@fnet.or.kr",
# 	"user_pw": "123456",
# 	"project_id": 145,
# 	"analysis_id": 158,
# 	"database": {
# 		"DB_USER": "dbadmin",
# 		"DB_PASSWORD": "INIT@1234",
# 		"DB_URL": "100.100.100.210:5432",
# 		"DB_DATABASE": "omop",
# 		"DB_SCHEMA": "cdm_hira_2012",
# 		"DB_HOST": "100.100.100.210",
# 		"DB_PORT": "5432"
# 	}
# }

# %%
aggregation.login()
# Out:
# ==========> login
# ==============================
# API_LOGIN :  <RequestsCookieJar[<Cookie token=s%3AeyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjUsImxwbSI6MTU5ODQ4NTQzNDA0MywidHMiOjE2NjIzNDUyMzIxNzgsImlhdCI6MTY2MjM0NTIzMn0.MKxp1jo2lAr8k5OHtjIB-INVxb6vec74UxQY-AmuTws.MA4fzfnOSXGGvXzdBzEzRkP9aALw1E4i0gYBkJXBmiw for qa-api.feedernet.kr/>]>
# > login success
# True

# %%
aggregation.get_images()
# Out:
# ==============================
# API_LIST_CONTAINER_IMAGES URL :  https://qa-api.feedernet.kr/api/container-images
# API_LIST_CONTAINER_IMAGES : RESULT :  {'data': {'images': [{'id': 1, 'image': 'docker.evidnet.co.kr/base-images/evidnet/tensorflow:latest', 'description': None, 'dockerfileContent': None}]}, 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjUsImxwbSI6MTU5ODQ4NTQzNDA0MywidHMiOjE2NjIzNDUyNDI4MDIsImlhdCI6MTY2MjM0NTIzMn0.7ZEmVcs-2O8Z0ozR4f1IHjOGfyjx-9CL-MmU-lzDfDg'}
# {'data': {'images': [{'id': 1,
#     'image': 'docker.evidnet.co.kr/base-images/evidnet/tensorflow:latest',
#     'description': None,
#     'dockerfileContent': None}]},
#  'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjUsImxwbSI6MTU5ODQ4NTQzNDA0MywidHMiOjE2NjIzNDUyNDI4MDIsImlhdCI6MTY2MjM0NTIzMn0.7ZEmVcs-2O8Z0ozR4f1IHjOGfyjx-9CL-MmU-lzDfDg'}

# %%
aggregation.get_cdms()
# Out:
# ==============================
# API_LIST_CDM URL :  https://qa-api.feedernet.kr/api/project/145/analysis/158/cdm
# API_LIST_CDM : RESULT :  {'data': {'list': [{'id': 31, 'name': 'FNET4_SYNPUF', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 32, 'name': 'FNET4_HIRA2012', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 33, 'name': 'FNET4_HIRA2013', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 34, 'name': 'FNET4_HIRA2014', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 35, 'name': 'FNET4_HIRA2015', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 36, 'name': 'FNET4_HIRA2016', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 37, 'name': 'FNET4_HIRA2017', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 4', 'orgName': 'Open Database 4', 'orgId': 15, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 24, 'name': 'FNET3_SYNPUF', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 25, 'name': 'FNET3_HIRA2012', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 26, 'name': 'FNET3_HIRA2013', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 27, 'name': 'FNET3_HIRA2014', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 28, 'name': 'FNET3_HIRA2015', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 29, 'name': 'FNET3_HIRA2016', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 30, 'name': 'FNET3_HIRA2017', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 3', 'orgName': 'Open Database 3', 'orgId': 14, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 9, 'name': 'FNET1_SYNPUF', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 1', 'orgName': 'Open Database 1', 'orgId': 13, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 11, 'name': 'FNET1_HIRA2012', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 1', 'orgName': 'Open Database 1', 'orgId': 13, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 13, 'name': 'FNET1_HIRA2013', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 1', 'orgName': 'Open Database 1', 'orgId': 13, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 14, 'name': 'FNET1_HIRA2014', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 1', 'orgName': 'Open Database 1', 'orgId': 13, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 15, 'name': 'FNET1_HIRA2015', 'cdmVersion': 'OMOP CDM v5.3.0', 'hrName': 'Open Database 1', 'orgName': 'Open Database 1', 'orgId': 13, 'orgBlockDBAccess': 0, 'permLevel': 'allow', 'requested': False}, {'id': 16,  ...
# {'data': {'list': [{'id': 31,
#     'name': 'FNET4_SYNPUF',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 32,
#     'name': 'FNET4_HIRA2012',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 33,
#     'name': 'FNET4_HIRA2013',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 34,
#     'name': 'FNET4_HIRA2014',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 35,
#     'name': 'FNET4_HIRA2015',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 36,
#     'name': 'FNET4_HIRA2016',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 37,
#     'name': 'FNET4_HIRA2017',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 4',
#     'orgName': 'Open Database 4',
#     'orgId': 15,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 24,
#     'name': 'FNET3_SYNPUF',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 25,
#     'name': 'FNET3_HIRA2012',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 26,
#     'name': 'FNET3_HIRA2013',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 27,
#     'name': 'FNET3_HIRA2014',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 28,
#     'name': 'FNET3_HIRA2015',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 29,
#     'name': 'FNET3_HIRA2016',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 30,
#     'name': 'FNET3_HIRA2017',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 3',
#     'orgName': 'Open Database 3',
#     'orgId': 14,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 9,
#     'name': 'FNET1_SYNPUF',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 11,
#     'name': 'FNET1_HIRA2012',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 13,
#     'name': 'FNET1_HIRA2013',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 14,
#     'name': 'FNET1_HIRA2014',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 15,
#     'name': 'FNET1_HIRA2015',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 16,
#     'name': 'FNET1_HIRA2016',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 17,
#     'name': 'FNET1_HIRA2017',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 1',
#     'orgName': 'Open Database 1',
#     'orgId': 13,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 10,
#     'name': 'FNET2_SYNPUF',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 12,
#     'name': 'FNET2_HIRA2012',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 18,
#     'name': 'FNET2_HIRA2013',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 19,
#     'name': 'FNET2_HIRA2014',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 20,
#     'name': 'FNET2_HIRA2015',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 21,
#     'name': 'FNET2_HIRA2016',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 22,
#     'name': 'FNET2_HIRA2017',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'Open Database 2',
#     'orgName': 'Open Database 2',
#     'orgId': 12,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 8,
#     'name': 'CDM_HIRA_2016',
#     'cdmVersion': '5.3.0',
#     'hrName': 'EvidNet_DQM',
#     'orgName': 'EvidNet_DQM',
#     'orgId': 11,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 23,
#     'name': 'TEST_SYNPUF',
#     'cdmVersion': '5.3.0',
#     'hrName': 'EvidNet_DQM',
#     'orgName': 'EvidNet_DQM',
#     'orgId': 11,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 3,
#     'name': '199_hira_2016',
#     'cdmVersion': '5.3.0',
#     'hrName': '198 origin',
#     'orgName': '198 origin',
#     'orgId': 6,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 6,
#     'name': '199_hira2016_from_204_18002',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'ORG204-18002',
#     'orgName': 'ORG204-18002',
#     'orgId': 4,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 2,
#     'name': 'synpuf_in_204_18001',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'ORG204-18001',
#     'orgName': 'ORG204-18001',
#     'orgId': 2,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 4,
#     'name': '199_hira2016_from_204_18001',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'ORG204-18001',
#     'orgName': 'ORG204-18001',
#     'orgId': 2,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 7,
#     'name': 'CDM_HIRA_2016',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': 'ORG204-18001',
#     'orgName': 'ORG204-18001',
#     'orgId': 2,
#     'orgBlockDBAccess': 2,
#     'permLevel': 'allow',
#     'requested': False},
#    {'id': 1,
#     'name': 'qa_synpuf_9900',
#     'cdmVersion': 'OMOP CDM v5.3.0',
#     'hrName': '에비드넷',
#     'orgName': '에비드넷',
#     'orgId': 1,
#     'orgBlockDBAccess': 0,
#     'permLevel': 'allow',
#     'requested': False}],
#   'totalCount': 36,
#   'page': 1,
#   'pageSize': 36},
#  'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1aWQiOjUsImxwbSI6MTU5ODQ4NTQzNDA0MywidHMiOjE2NjIzNDM4MTA3NDIsImlhdCI6MTY2MjM0Mzc4OX0.rY_tqkmfhwWWvMbWWoDLqZP83WAXh8XsBIkqEtv96mg'}

# %% [markdown]
# # Analysis Flow
# ## Precondition
# Create User Id and Get the status of analyser of your chosen organization
# ## Analysis
# 1. Log in with your id and password
# 1. Create Project and get projectId
# 1. Create Analysis and get analysisId
# 1. Get Container Images
# 1. Create your model
# 1. run the model

# %%
# my aggregation server
class MyServer(AggregationServer):
    def test(self):
        print(self.test)
    def learning_stop_condition(self):
        return self.round == 100

# %%
def get_cdms():
    client = DefaultApi()
    data = client.cdms_get(_preload_content=False)
    data = json.loads(data.data.decode('utf-8'))   
    return data

# %%
# create analysis
def create_analysis():
    client = DefaultApi()
    data = client.analyses_post(_preload_content=False)
    data = json.loads(data.data.decode('utf-8'))
    analysisId = data['data']['analysis']['analysisId']
    return analysisId

# %%
def create_analysis1():
    client = DefaultApi()
    data = client.analyses_post(_preload_content=False)
    data = json.loads(data.data.decode('utf-8'))   
    return data

# %%
cdmInfos = get_cdms()
cdms = map(lambda x: x["cdmId"], cdmInfos['data']['Items'])
list(cdms)

# %%
data = create_analysis1()
data

# %%
# get predefined url for upload
def get_predefined_url_4_upload(round, analysisId):
    client = DefaultApi()
    data = client.analyses_analysis_id_predefined_url_get(round, analysisId, _preload_content=False)
    data = json.loads(data.data.decode('utf-8'))
    url = data['data']
    return url
analysisId = create_analysis()
url = get_predefined_url_4_upload(1, analysisId)
url

# %%
# program machine learning code with db connection(environment variable)
# create and upload zip file to predefined url
def zip_fl_execution(zip_dir_name, zip_file_name):
    if not os.path.isdir(zip_dir_name):
        raise Exception("not a directory")
    shutil.make_archive(zip_file_name, 'zip', zip_dir_name)
    
def getSize(fileobject):
    fileobject.seek(0,2) # move the cursor to the end of the file
    size = fileobject.tell()
    return size

zip_dir_name = 'sample_execution'
zip_file_name = 'round_1_model'
zip_fl_execution(zip_dir_name, zip_file_name)

# upload file to S3 using presigned URL
headers = {'Content-Length': 'application/octet-stream'}
# files = { 'file': open(zip_file_name+'.zip', 'rb')}
# with open(zip_file_name+'.zip', 'rb') as data:
#     size = getSize(data)
#     headers = {'Content-Length': str(size)}
#     r = requests.post(url, files=files, headers=headers)
# r = requests.put(url, files=files)
with open(zip_file_name+'.zip', 'rb') as data:
    r=requests.put(url, data=data)
print(r.status_code)

# %%
# get presigned url for download
def get_predefined_url_4_download(round, analysisId):
    client = DefaultApi()
    data = client.analyses_analysis_id_rounds_round_put(analysisId, round, _preload_content=False)
    data = json.loads(data.data.decode('utf-8'))
    url = data['presignedGetUrl']
    return url

get_url = get_predefined_url_4_download(1, analysisId)
get_url
